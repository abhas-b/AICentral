# %%
from google.colab import userdata
from huggingface_hub import login
from transformers import AutoTokenizer


hf_token = userdata.get("HF_TOKEN")
login(hf_token)

# %%
# !nvidia-smi
# Out:
# Thu Apr 30 02:40:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
tokenizer = AutoTokenizer.from_pretrained('meta-llama/Llama-3.1-8B', trust_remote_code=True)

# %%
text = "This is a sample text used for checking out pretrained tokenizer"
tokens = tokenizer.encode(text)
tokens
# Out:
# [128000, 2028, 374, 264, 6205, 1495, 1511, 369, 13598, 704, 81769, 47058]

# %%
tokenizer.decode(tokens)
# Out:
# '<|begin_of_text|>This is a sample text used for checking out pretrained tokenizer'

# %%
print(f"Number of characters: {len(text)}, word count: {len(text.split())}, number of tokens: {len(tokens)}")
# Out:
# Number of characters: 64, word count: 11, number of tokens: 12

# %%
tokenizer.batch_decode(tokens)
# Out:
# ['<|begin_of_text|>This is a sample text used for checking out pretrained tokenizer']

# %%
len(tokenizer.vocab)
# Out:
# 128256

# %% [markdown]
# # Chat Model

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.1-8B-Instruct", trust_remote_code=True)
# Out:
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role":"user", "content":"Tell me a joke"}
]

# %%
prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
print(prompt)
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# You are a helpful assistant<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Tell me a joke<|eot_id|><|start_header_id|>assistant<|end_header_id|>
