# %%
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

# %%
normal_dist = stats.norm(loc=0, scale=1)

# %%
pdf_at_zero = normal_dist.pdf(0)
print(f"Probability density at 0: {pdf_at_zero}")
# Out:
# Probability density at 0: 0.3989422804014327

# %%
# Generate 5 random samples

normal_dist.rvs(size=5)
# Out:
# array([ 0.21322733,  0.2514169 , -0.44271003, -1.39273903, -0.16473944])

# %%
# Calculate cumulative probability P(X<=1)

normal_dist.cdf(1)
# Out:
# np.float64(0.8413447460685429)

# %%
x = np.linspace(-5, 5, 100)
plt.plot(x, normal_dist.pdf(x))
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.show()

# %% [markdown]
# # Normal Distribution

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5,1000)

# %%
pdf = norm.pdf(x, loc=0, scale=1)

# %%
plt.plot(x,pdf, color='red')
plt.xlabel('X')
plt.ylabel('Normal Distribution Density');
