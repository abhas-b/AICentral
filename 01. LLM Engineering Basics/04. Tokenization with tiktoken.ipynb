# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = encoding.encode("This is a sample text for tokenization. I'm trying this out.")
tokens
# Out:
# [2500, 382, 261, 10176, 2201, 395, 6602, 2860, 13, 5477, 6700, 495, 842, 13]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"Token id {token_id} = {token_text}")
# Out:
# Token id 2500 = This
# Token id 382 =  is
# Token id 261 =  a
# Token id 10176 =  sample
# Token id 2201 =  text
# Token id 395 =  for
# Token id 6602 =  token
# Token id 2860 = ization
# Token id 13 = .
# Token id 5477 =  I'm
# Token id 6700 =  trying
# Token id 495 =  this
# Token id 842 =  out
# Token id 13 = .
